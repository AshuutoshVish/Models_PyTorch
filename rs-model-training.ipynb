# %%
import torch
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
df = pd.read_csv("/kaggle/input/interview-selection-dataset/Data - Base.csv")
df.shape
# Out:
# (21256, 52)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21256 entries, 0 to 21255
# Data columns (total 52 columns):
#  #   Column                                                                                                                                             Non-Null Count  Dtype
# ---  ------                                                                                                                                             --------------  -----
#  0   Name                                                                                                                                               21256 non-null  object
#  1   Age                                                                                                                                                21256 non-null  object
#  2   Gender                                                                                                                                             21256 non-null  object
#  3   Type of Graduation/Post Graduation                                                                                                                 21256 non-null  object
#  4   Marital status                                                                                                                                     21256 non-null  object
#  5   Mode of interview given by candidate?                                                                                                              21256 non-null  object
#  6   Pre Interview Check                                                                                                                                21256 non-null  object
#  7   Fluency in English based on introduction                                                                                                           21256 non-null  object
#  8   Confidence based on Introduction (English)                                                                                                         21256 non-null  object
#  9   Confidence based on the topic given                                                                                                                18709 non-null  object
#  10  Confidence Based on the PPT Question                                                                                                               18705 non-null  object
#  11  Confidence based on the sales scenario                                                                                                             18705 non-null  object
#  12  Structured Thinking (In regional only)                                                                                                             18709 non-null  object
#  13  Structured Thinking Based on the PPT Question                                                                                                      18705 non-null  object
#  14  Structured Thinking( Call pitch)                                                                                                                   18705 non-null  object
#  15  Regional fluency based on the topic given                                                                                                          18709 non-null  object
#  16  Regional fluency Based on the PPT Question                                                                                                         18705 non-null  object
#  17  Regional fluency based on the  sales scenario                                                                                                      18705 non-null  object
#  18  Does the candidate has mother tongue influence while speaking english.                                                                             21256 non-null  object
#  19  Has acquaintance in Company and has spoken to him/her before applying?                                                                             21256 non-null  object
#  20  Candidate Status                                                                                                                                   18709 non-null  object
#  21  Last Fixed CTC (lakhs)                                                                                                                             18709 non-null  object
#  22  Currently Employed                                                                                                                                 18709 non-null  object
#  23  Experienced candidate - (Experience in months)                                                                                                     18709 non-null  object
#  24  Experienced Candidate (Nature of work)                                                                                                             18688 non-null  object
#  25  What was the type of Role?	                                                                                                                        18709 non-null  object
#  26  How many slides candidate have submitted in PPT?                                                                                                   18705 non-null  object
#  27  Call-pitch Elements used during the call Sales Scenario                                                                                            18705 non-null  object
#  28  But, my child's exam are going on now, so we will keep the counselling session after the exams get over.(Time: Favourable pitch: Counsellor hype)  18705 non-null  object
#  29  Let me discuss it with my child                                                                                                                    18705 non-null  object
#  30  Sir being in education industry I know this is a marketing gimmick and at the end of the day you'll be selling the app.                            18705 non-null  object
#  31  Role acceptance                                                                                                                                    18702 non-null  object
#  32  Interview Verdict                                                                                                                                  18704 non-null  object
#  33  Candidate is willing to relocate                                                                                                                   18702 non-null  object
#  34  Role Location to be given to the candidate                                                                                                         18702 non-null  object
#  35  Comments                                                                                                                                           18702 non-null  object
#  36  RedFlags Comments in Interview                                                                                                                     18702 non-null  object
#  37  Confidence based on Introduction (English).1                                                                                                       21256 non-null  int64
#  38  Confidence based on the topic given  .1                                                                                                            21256 non-null  int64
#  39  Confidence Based on the PPT Question.1                                                                                                             21256 non-null  int64
#  40  Confidence based on the sales scenario.1                                                                                                           21256 non-null  int64
#  41  Structured Thinking (In regional only).1                                                                                                           21256 non-null  int64
#  42  Structured Thinking Based on the PPT Question.1                                                                                                    21256 non-null  int64
#  43  Structured Thinking( Call pitch).1                                                                                                                 21256 non-null  int64
#  44  Regional fluency based on the topic given  .1                                                                                                      21256 non-null  int64
#  45  Regional fluency Based on the PPT Question.1                                                                                                       18705 non-null  float64
#  46  Regional fluency based on the  sales scenario.1                                                                                                    18705 non-null  float64
#  47  Confidence Score                                                                                                                                   21256 non-null  int64
#  48  Structured Thinking Score                                                                                                                          21256 non-null  int64
#  49  Regional Fluency Score                                                                                                                             21256 non-null  int64
#  50  Total Score                                                                                                                                        21256 non-null  int64
#  51  Whether joined the company or not
#                                                                                                                  21256 non-null  object
# dtypes: float64(2), int64(12), object(38)
# memory usage: 8.4+ MB

# %%
df.isna().sum()
# Out:
# Name                                                                                                                                                    0
# Age                                                                                                                                                     0
# Gender                                                                                                                                                  0
# Type of Graduation/Post Graduation                                                                                                                      0
# Marital status                                                                                                                                          0
# Mode of interview given by candidate?                                                                                                                   0
# Pre Interview Check                                                                                                                                     0
# Fluency in English based on introduction                                                                                                                0
# Confidence based on Introduction (English)                                                                                                              0
# Confidence based on the topic given                                                                                                                  2547
# Confidence Based on the PPT Question                                                                                                                 2551
# Confidence based on the sales scenario                                                                                                               2551
# Structured Thinking (In regional only)                                                                                                               2547
# Structured Thinking Based on the PPT Question                                                                                                        2551
# Structured Thinking( Call pitch)                                                                                                                     2551
# Regional fluency based on the topic given                                                                                                            2547
# Regional fluency Based on the PPT Question                                                                                                           2551
# Regional fluency based on the  sales scenario                                                                                                        2551
# Does the candidate has mother tongue influence while speaking english.                                                                                  0
# Has acquaintance in Company and has spoken to him/her before applying?                                                                                  0
# Candidate Status                                                                                                                                     2547
# Last Fixed CTC (lakhs)                                                                                                                               2547
# Currently Employed                                                                                                                                   2547
# Experienced candidate - (Experience in months)                                                                                                       2547
# Experienced Candidate (Nature of work)                                                                                                               2568
# What was the type of Role?\t                                                                                                                         2547
# How many slides candidate have submitted in PPT?                                                                                                     2551
# Call-pitch Elements used during the call Sales Scenario                                                                                              2551
# But, my child's exam are going on now, so we will keep the counselling session after the exams get over.(Time: Favourable pitch: Counsellor hype)    2551
# Let me discuss it with my child                                                                                                                      2551
# Sir being in education industry I know this is a marketing gimmick and at the end of the day you'll be selling the app.                              2551
# Role acceptance                                                                                                                                      2554
# Interview Verdict                                                                                                                                    2552
# Candidate is willing to relocate                                                                                                                     2554
# Role Location to be given to the candidate                                                                                                           2554
# Comments                                                                                                                                             2554
# RedFlags Comments in Interview                                                                                                                       2554
# Confidence based on Introduction (English).1                                                                                                            0
# Confidence based on the topic given  .1                                                                                                                 0
# Confidence Based on the PPT Question.1                                                                                                                  0
# Confidence based on the sales scenario.1                                                                                                                0
# Structured Thinking (In regional only).1                                                                                                                0
# Structured Thinking Based on the PPT Question.1                                                                                                         0
# Structured Thinking( Call pitch).1                                                                                                                      0
# Regional fluency based on the topic given  .1                                                                                                           0
# Regional fluency Based on the PPT Question.1                                                                                                         2551
# Regional fluency based on the  sales scenario.1                                                                                                      2551
# Confidence Score                                                                                                                                        0
# Structured Thinking Score                                                                                                                               0
# Regional Fluency Score                                                                                                                                  0
# Total Score                                                                                                                                             0
# Whether joined the company or not\n                                                                                                                     0
# dtype: int64

# %%
df.dropna(inplace=True)
df.reset_index(drop=True, inplace=True)
df.shape
# Out:
# (18681, 52)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.drop_duplicates(inplace=True)
df.duplicated().sum()
# Out:
# 0

# %%
df.isna().sum()
# Out:
# Name                                                                                                                                                 0
# Age                                                                                                                                                  0
# Gender                                                                                                                                               0
# Type of Graduation/Post Graduation                                                                                                                   0
# Marital status                                                                                                                                       0
# Mode of interview given by candidate?                                                                                                                0
# Pre Interview Check                                                                                                                                  0
# Fluency in English based on introduction                                                                                                             0
# Confidence based on Introduction (English)                                                                                                           0
# Confidence based on the topic given                                                                                                                  0
# Confidence Based on the PPT Question                                                                                                                 0
# Confidence based on the sales scenario                                                                                                               0
# Structured Thinking (In regional only)                                                                                                               0
# Structured Thinking Based on the PPT Question                                                                                                        0
# Structured Thinking( Call pitch)                                                                                                                     0
# Regional fluency based on the topic given                                                                                                            0
# Regional fluency Based on the PPT Question                                                                                                           0
# Regional fluency based on the  sales scenario                                                                                                        0
# Does the candidate has mother tongue influence while speaking english.                                                                               0
# Has acquaintance in Company and has spoken to him/her before applying?                                                                               0
# Candidate Status                                                                                                                                     0
# Last Fixed CTC (lakhs)                                                                                                                               0
# Currently Employed                                                                                                                                   0
# Experienced candidate - (Experience in months)                                                                                                       0
# Experienced Candidate (Nature of work)                                                                                                               0
# What was the type of Role?\t                                                                                                                         0
# How many slides candidate have submitted in PPT?                                                                                                     0
# Call-pitch Elements used during the call Sales Scenario                                                                                              0
# But, my child's exam are going on now, so we will keep the counselling session after the exams get over.(Time: Favourable pitch: Counsellor hype)    0
# Let me discuss it with my child                                                                                                                      0
# Sir being in education industry I know this is a marketing gimmick and at the end of the day you'll be selling the app.                              0
# Role acceptance                                                                                                                                      0
# Interview Verdict                                                                                                                                    0
# Candidate is willing to relocate                                                                                                                     0
# Role Location to be given to the candidate                                                                                                           0
# Comments                                                                                                                                             0
# RedFlags Comments in Interview                                                                                                                       0
# Confidence based on Introduction (English).1                                                                                                         0
# Confidence based on the topic given  .1                                                                                                              0
# Confidence Based on the PPT Question.1                                                                                                               0
# Confidence based on the sales scenario.1                                                                                                             0
# Structured Thinking (In regional only).1                                                                                                             0
# Structured Thinking Based on the PPT Question.1                                                                                                      0
# Structured Thinking( Call pitch).1                                                                                                                   0
# Regional fluency based on the topic given  .1                                                                                                        0
# Regional fluency Based on the PPT Question.1                                                                                                         0
# Regional fluency based on the  sales scenario.1                                                                                                      0
# Confidence Score                                                                                                                                     0
# Structured Thinking Score                                                                                                                            0
# Regional Fluency Score                                                                                                                               0
# Total Score                                                                                                                                          0
# Whether joined the company or not\n                                                                                                                  0
# dtype: int64

# %%
df.columns = df.columns.str.strip().str.replace(" ", "_").str.lower()

# %%
df.columns
# Out:
# Index(['name', 'age', 'gender', 'type_of_graduation/post_graduation',
#        'marital_status', 'mode_of_interview_given_by_candidate?',
#        'pre_interview_check', 'fluency_in_english_based_on_introduction',
#        'confidence_based_on_introduction_(english)',
#        'confidence_based_on_the_topic_given',
#        'confidence_based_on_the_ppt_question',
#        'confidence_based_on_the_sales_scenario',
#        'structured_thinking_(in_regional_only)',
#        'structured_thinking_based_on_the_ppt_question',
#        'structured_thinking(_call_pitch)',
#        'regional_fluency_based_on_the_topic_given',
#        'regional_fluency_based_on_the_ppt_question',
#        'regional_fluency_based_on_the__sales_scenario',
#        'does_the_candidate_has_mother_tongue_influence_while_speaking_english.',
#        'has_acquaintance_in_company_and_has_spoken_to_him/her_before_applying?',
#        'candidate_status', 'last_fixed_ctc_(lakhs)', 'currently_employed',
#        'experienced_candidate_-_(experience_in_months)',
#        'experienced_candidate_(nature_of_work)', 'what_was_the_type_of_role?',
#        'how_many_slides_candidate_have_submitted_in_ppt?',
#        'call-pitch_elements_used_during_the_call_sales_scenario',
#        'but,_my_child's_exam_are_going_on_now,_so_we_will_keep_the_counselling_session_after_the_exams_get_over.(time:_favourable_pitch:_counsellor_hype)',
#        'let_me_discuss_it_with_my_child',
#        'sir_being_in_education_industry_i_know_this_is_a_marketing_gimmick_and_at_the_end_of_the_day_you'll_be_selling_the_app.',
#        'role_acceptance', 'interview_verdict',
#        'candidate_is_willing_to_relocate',
#        'role_location_to_be_given_to_the_candidate', 'comments',
#        'redflags_comments_in_interview',
#        'confidence_based_on_introduction_(english).1',
#        'confidence_based_on_the_topic_given__.1',
#        'confidence_based_on_the_ppt_question.1',
#        'confidence_based_on_the_sales_scenario.1',
#        'structured_thinking_(in_regional_only).1',
#        'structured_thinking_based_on_the_ppt_question.1',
#        'structured_thinking(_call_pitch).1',
#        'regional_fluency_based_on_the_topic_given__.1',
#        'regional_fluency_based_on_the_ppt_question.1',
#        'regional_fluency_based_on_the__sales_scenario.1', 'confidence_score',
#        'structured_thinking_score', 'regional_fluency_score', 'total_score',
#        'whether_joined_the_company_or_not'],
#       dtype='object')

# %%
df.rename(columns={'does_the_candidate_has_mother_tongue_influence_while_speaking_english': 'mother_tongue_influence',
                   'has_acquaintance_in_company_and_has_spoken_to_him/her_before_applying?	' : 'spoken_before_applying?',
                   "but,_my_child's_exam_are_going_on_now,_so_we_will_keep_the_counselling_session_after_the_exams_get_over.(time:_favourable_pitch:_counsellor_hype)" : "father_reply",
                   "sir_being_in_education_industry_i_know_this_is_a_marketing_gimmick_and_at_the_end_of_the_day_you'll_be_selling_the_app.": "reply_being_in_education",
                   "mode_of_interview_given_by_candidate?" :"interview_mode",
                   'does_the_candidate_has_mother_tongue_influence_while_speaking_english.':'mother_tongue_influence',
                   'has_acquaintance_in_company_and_has_spoken_to_him/her_before_applying?':'acquaintance_in_company',
                   'call-pitch_elements_used_during_the_call_sales_scenario': 'call_pitch_elements',
                   'whether_joined_the_company_or_not':'joined_or_not'
                  },inplace=True)

# %%
df['joined_or_not'] = df['joined_or_not'].map({'Joined': 1, 'Yes':1, 'No':0, 'Not Joined': 0})

# %%
df['age'] = df['age'].replace('32+', '32').astype(int)

# %%
bins = [0, 19, 21, 24, 27, 30, 32, float('inf')]
labels = ['0-19', '20-21', '22-24', '25-27', '28-30', '31-32', '60+']

df['age'] = pd.cut(df['age'], bins=bins, labels=labels, right=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18681 entries, 0 to 18680
# Data columns (total 52 columns):
#  #   Column                                            Non-Null Count  Dtype
# ---  ------                                            --------------  -----
#  0   name                                              18681 non-null  object
#  1   age                                               18681 non-null  category
#  2   gender                                            18681 non-null  object
#  3   type_of_graduation/post_graduation                18681 non-null  object
#  4   marital_status                                    18681 non-null  object
#  5   interview_mode                                    18681 non-null  object
#  6   pre_interview_check                               18681 non-null  object
#  7   fluency_in_english_based_on_introduction          18681 non-null  object
#  8   confidence_based_on_introduction_(english)        18681 non-null  object
#  9   confidence_based_on_the_topic_given               18681 non-null  object
#  10  confidence_based_on_the_ppt_question              18681 non-null  object
#  11  confidence_based_on_the_sales_scenario            18681 non-null  object
#  12  structured_thinking_(in_regional_only)            18681 non-null  object
#  13  structured_thinking_based_on_the_ppt_question     18681 non-null  object
#  14  structured_thinking(_call_pitch)                  18681 non-null  object
#  15  regional_fluency_based_on_the_topic_given         18681 non-null  object
#  16  regional_fluency_based_on_the_ppt_question        18681 non-null  object
#  17  regional_fluency_based_on_the__sales_scenario     18681 non-null  object
#  18  mother_tongue_influence                           18681 non-null  object
#  19  acquaintance_in_company                           18681 non-null  object
#  20  candidate_status                                  18681 non-null  object
#  21  last_fixed_ctc_(lakhs)                            18681 non-null  object
#  22  currently_employed                                18681 non-null  object
#  23  experienced_candidate_-_(experience_in_months)    18681 non-null  object
#  24  experienced_candidate_(nature_of_work)            18681 non-null  object
#  25  what_was_the_type_of_role?                        18681 non-null  object
#  26  how_many_slides_candidate_have_submitted_in_ppt?  18681 non-null  object
#  27  call_pitch_elements                               18681 non-null  object
#  28  father_reply                                      18681 non-null  object
#  29  let_me_discuss_it_with_my_child                   18681 non-null  object
#  30  reply_being_in_education                          18681 non-null  object
#  31  role_acceptance                                   18681 non-null  object
#  32  interview_verdict                                 18681 non-null  object
#  33  candidate_is_willing_to_relocate                  18681 non-null  object
#  34  role_location_to_be_given_to_the_candidate        18681 non-null  object
#  35  comments                                          18681 non-null  object
#  36  redflags_comments_in_interview                    18681 non-null  object
#  37  confidence_based_on_introduction_(english).1      18681 non-null  int64
#  38  confidence_based_on_the_topic_given__.1           18681 non-null  int64
#  39  confidence_based_on_the_ppt_question.1            18681 non-null  int64
#  40  confidence_based_on_the_sales_scenario.1          18681 non-null  int64
#  41  structured_thinking_(in_regional_only).1          18681 non-null  int64
#  42  structured_thinking_based_on_the_ppt_question.1   18681 non-null  int64
#  43  structured_thinking(_call_pitch).1                18681 non-null  int64
#  44  regional_fluency_based_on_the_topic_given__.1     18681 non-null  int64
#  45  regional_fluency_based_on_the_ppt_question.1      18681 non-null  float64
#  46  regional_fluency_based_on_the__sales_scenario.1   18681 non-null  float64
#  47  confidence_score                                  18681 non-null  int64
#  48  structured_thinking_score                         18681 non-null  int64
#  49  regional_fluency_score                            18681 non-null  int64
#  50  total_score                                       18681 non-null  int64
#  51  joined_or_not                                     18681 non-null  int64
# dtypes: category(1), float64(2), int64(13), object(36)
# memory usage: 7.3+ MB

# %%
num_df = df.select_dtypes(include=['int64', 'float64']).drop(columns=['joined_or_not'])
num_df.head()
# Out:
#    confidence_based_on_introduction_(english).1  \
# 0                                             3
# 1                                             3
# 2                                             2
# 3                                             3
# 4                                             2
#
#    confidence_based_on_the_topic_given__.1  \
# 0                                        2
# 1                                        3
# 2                                        3
# 3                                        3
# 4                                        3
#
#    confidence_based_on_the_ppt_question.1  \
# 0                                       3
# 1                                       3
# 2                                       2
# 3                                       3
# 4                                       2
#
#    confidence_based_on_the_sales_scenario.1  \
# 0                                         3
# 1                                         3
# 2                                         3
# 3                                         3
# 4                                         3
#
#    structured_thinking_(in_regional_only).1  \
# 0                                         2
# 1                                         3
# 2                                         3
# 3                                         3
# 4                                         2
#
#    structured_thinking_based_on_the_ppt_question.1  \
# 0                                                3
# 1                                                3
# 2                                                3
# 3                                                3
# 4                                                2
#
#    structured_thinking(_call_pitch).1  \
# 0                                   2
# 1                                   3
# 2                                   3
# 3                                   3
# 4                                   1
#
#    regional_fluency_based_on_the_topic_given__.1  \
# 0                                              1
# 1                                              3
# 2                                              3
# 3                                              3
# 4                                              3
#
#    regional_fluency_based_on_the_ppt_question.1  \
# 0                                           1.0
# 1                                           3.0
# 2                                           1.0
# 3                                           3.0
# 4                                           1.0
#
#    regional_fluency_based_on_the__sales_scenario.1  confidence_score  \
# 0                                              1.0                11
# 1                                              3.0                12
# 2                                              3.0                10
# 3                                              3.0                12
# 4                                              3.0                10
#
#    structured_thinking_score  regional_fluency_score  total_score
# 0                          7                       3           42
# 1                          9                       9           60
# 2                          9                       7           52
# 3                          9                       9           60
# 4                          5                       7           44

# %% [markdown]
# # Standard scaling

# %%
scaler = StandardScaler()
num_df_scaled = pd.DataFrame(scaler.fit_transform(num_df), columns=num_df.columns)

# Original replace with new
df = df.drop(columns=num_df.columns) 
df = pd.concat([df, num_df_scaled], axis=1)  
df.shape
# Out:
# (18681, 52)

# %%
df
# Out:
#          name    age  gender type_of_graduation/post_graduation  \
# 0      parida  25-27  Female            Masters in data science
# 1      shreej  28-30  Female                         BSc or MSc
# 2      ms6744  25-27  Female                       B.E / B-Tech
# 3      aswalu  22-24    Male                       B.E / B-Tech
# 4      aniket  22-24    Male                              BA/MA
# ...       ...    ...     ...                                ...
# 18676  rajivt  28-30    Male                         BSc or MSc
# 18677  amitmk  25-27    Male                       B.E / B-Tech
# 18678  Seshag  31-32    Male                              B.ARC
# 18679  melbin  25-27    Male                       B.E / B-Tech
# 18680  Abbind  28-30    Male                                MBA
#
#       marital_status interview_mode         pre_interview_check  \
# 0          Unmarried         Mobile  Proceed with the Interview
# 1          Unmarried         Mobile  Proceed with the Interview
# 2          Unmarried         Mobile  Proceed with the Interview
# 3          Unmarried         Laptop  Proceed with the Interview
# 4          Unmarried         Mobile  Proceed with the Interview
# ...              ...            ...                         ...
# 18676      Unmarried         Mobile  Proceed with the Interview
# 18677      Unmarried         Mobile  Proceed with the Interview
# 18678        Married         Laptop  Proceed with the Interview
# 18679      Unmarried         Mobile  Proceed with the Interview
# 18680        Married         Mobile  Proceed with the Interview
#
#                 fluency_in_english_based_on_introduction  \
# 0      Able to speak sentences in a clear/coherent wa...
# 1      Able to speak sentences in a clear/coherent wa...
# 2      Able to speak sentences in a clear/coherent wa...
# 3      Able to speak sentences in a clear/coherent wa...
# 4      Taking gaps while speaking due to lack of cont...
# ...                                                  ...
# 18676  Able to speak sentences in a clear/coherent wa...
# 18677  Taking gaps while speaking due to lack of cont...
# 18678  Able to speak sentences in a clear/coherent wa...
# 18679  Able to speak sentences in a clear/coherent wa...
# 18680  Able to speak sentences in a clear/coherent wa...
#
#               confidence_based_on_introduction_(english)  \
# 0      Impactful - Good confidence throughout the Int...
# 1      Impactful - Good confidence throughout the Int...
# 2      Guarded Confidence - Confident in some areas a...
# 3      Impactful - Good confidence throughout the Int...
# 4      Guarded Confidence - Confident in some areas a...
# ...                                                  ...
# 18676  Impactful - Good confidence throughout the Int...
# 18677  Guarded Confidence - Confident in some areas a...
# 18678  Impactful - Good confidence throughout the Int...
# 18679  Impactful - Good confidence throughout the Int...
# 18680  Impactful - Good confidence throughout the Int...
#
#                      confidence_based_on_the_topic_given  ...  \
# 0      Guarded Confidence - Confident in some areas a...  ...
# 1      Impactful - Good confidence throughout the Int...  ...
# 2      Impactful - Good confidence throughout the Int...  ...
# 3      Impactful - Good confidence throughout the Int...  ...
# 4      Impactful - Good confidence throughout the Int...  ...
# ...                                                  ...  ...
# 18676  Impactful - Good confidence throughout the Int...  ...
# 18677  Impactful - Good confidence throughout the Int...  ...
# 18678  Impactful - Good confidence throughout the Int...  ...
# 18679  Impactful - Good confidence throughout the Int...  ...
# 18680  Guarded Confidence - Confident in some areas a...  ...
#
#       structured_thinking_(in_regional_only).1  \
# 0                                    -0.618598
# 1                                     0.985514
# 2                                     0.985514
# 3                                     0.985514
# 4                                    -0.618598
# ...                                        ...
# 18676                                 0.985514
# 18677                                -0.618598
# 18678                                 0.985514
# 18679                                 0.985514
# 18680                                -0.618598
#
#       structured_thinking_based_on_the_ppt_question.1  \
# 0                                            1.020654
# 1                                            1.020654
# 2                                            1.020654
# 3                                            1.020654
# 4                                           -0.556030
# ...                                               ...
# 18676                                       -0.556030
# 18677                                       -0.556030
# 18678                                        1.020654
# 18679                                        1.020654
# 18680                                        1.020654
#
#       structured_thinking(_call_pitch).1  \
# 0                              -0.424411
# 1                               1.006713
# 2                               1.006713
# 3                               1.006713
# 4                              -1.855535
# ...                                  ...
# 18676                           1.006713
# 18677                           1.006713
# 18678                           1.006713
# 18679                           1.006713
# 18680                          -0.424411
#
#       regional_fluency_based_on_the_topic_given__.1  \
# 0                                         -1.092966
# 1                                          0.979581
# 2                                          0.979581
# 3                                          0.979581
# 4                                          0.979581
# ...                                             ...
# 18676                                     -1.092966
# 18677                                      0.979581
# 18678                                      0.979581
# 18679                                      0.979581
# 18680                                     -1.092966
#
#       regional_fluency_based_on_the_ppt_question.1  \
# 0                                        -1.063625
# 1                                         1.024503
# 2                                        -1.063625
# 3                                         1.024503
# 4                                        -1.063625
# ...                                            ...
# 18676                                    -1.063625
# 18677                                     1.024503
# 18678                                     1.024503
# 18679                                     1.024503
# 18680                                    -1.063625
#
#       regional_fluency_based_on_the__sales_scenario.1 confidence_score  \
# 0                                           -1.043289         0.951490
# 1                                            1.060405         1.415087
# 2                                            1.060405         0.487893
# 3                                            1.060405         1.415087
# 4                                            1.060405         0.487893
# ...                                               ...              ...
# 18676                                        1.060405         1.415087
# 18677                                        1.060405         0.487893
# 18678                                        1.060405         1.415087
# 18679                                        1.060405         0.951490
# 18680                                       -1.043289         0.487893
#
#       structured_thinking_score regional_fluency_score total_score
# 0                     -0.022276              -1.320677   -0.198863
# 1                      1.256178               1.264403    1.509342
# 2                      1.256178               0.402709    0.750139
# 3                      1.256178               1.264403    1.509342
# 4                     -1.300729               0.402709   -0.009063
# ...                         ...                    ...         ...
# 18676                  0.616951              -0.458984    0.560339
# 18677                 -0.022276               1.264403    0.750139
# 18678                  1.256178               1.264403    1.509342
# 18679                  1.256178               1.264403    1.319541
# 18680                 -0.022276              -1.320677   -0.388664
#
# [18681 rows x 52 columns]

# %%
print(df.shape)  # Original DF size
print(num_df_scaled.shape)  # Scaled DF size
# Out:
# (18681, 52)
# (18681, 14)

# %% [markdown]
# # Categorial data

# %%
cat_df = df.select_dtypes(include=['object']).drop(columns=['name'])
cat_df.head()
# Out:
#    gender type_of_graduation/post_graduation marital_status interview_mode  \
# 0  Female            Masters in data science      Unmarried         Mobile
# 1  Female                         BSc or MSc      Unmarried         Mobile
# 2  Female                       B.E / B-Tech      Unmarried         Mobile
# 3    Male                       B.E / B-Tech      Unmarried         Laptop
# 4    Male                              BA/MA      Unmarried         Mobile
#
#           pre_interview_check  \
# 0  Proceed with the Interview
# 1  Proceed with the Interview
# 2  Proceed with the Interview
# 3  Proceed with the Interview
# 4  Proceed with the Interview
#
#             fluency_in_english_based_on_introduction  \
# 0  Able to speak sentences in a clear/coherent wa...
# 1  Able to speak sentences in a clear/coherent wa...
# 2  Able to speak sentences in a clear/coherent wa...
# 3  Able to speak sentences in a clear/coherent wa...
# 4  Taking gaps while speaking due to lack of cont...
#
#           confidence_based_on_introduction_(english)  \
# 0  Impactful - Good confidence throughout the Int...
# 1  Impactful - Good confidence throughout the Int...
# 2  Guarded Confidence - Confident in some areas a...
# 3  Impactful - Good confidence throughout the Int...
# 4  Guarded Confidence - Confident in some areas a...
#
#                  confidence_based_on_the_topic_given  \
# 0  Guarded Confidence - Confident in some areas a...
# 1  Impactful - Good confidence throughout the Int...
# 2  Impactful - Good confidence throughout the Int...
# 3  Impactful - Good confidence throughout the Int...
# 4  Impactful - Good confidence throughout the Int...
#
#                 confidence_based_on_the_ppt_question  \
# 0  Impactful - Good confidence throughout the Int...
# 1  Impactful - Good confidence throughout the Int...
# 2  Guarded Confidence - Confident in some areas a...
# 3  Impactful - Good confidence throughout the Int...
# 4  Guarded Confidence - Confident in some areas a...
#
#               confidence_based_on_the_sales_scenario  ...  \
# 0  Impactful - Good confidence throughout the sal...  ...
# 1  Impactful - Good confidence throughout the sal...  ...
# 2  Impactful - Good confidence throughout the sal...  ...
# 3  Impactful - Good confidence throughout the sal...  ...
# 4  Impactful - Good confidence throughout the sal...  ...
#
#                                  call_pitch_elements  \
# 0       Purpose of Call (Book a Counselling Session)
# 1  Introduction (Self Intro,Company Name), Purpos...
# 2             Introduction (Self Intro,Company Name)
# 3  Introduction (Self Intro,Company Name), Purpos...
# 4                                  None of the Above
#
#                                   father_reply  \
# 0                           Urgency using Time
# 1                             Asking Questions
# 2                           Urgency using Time
# 3  Urgency using Time, Urgency using situation
# 4          Urgency by creating counsellor Hype
#
#                      let_me_discuss_it_with_my_child  \
# 0                                  None of the above
# 1                                  None of the above
# 2  Decision Making: Major decision of child futur...
# 3                                  None of the above
# 4        Anticipation of objection from child's end:
#
#                  reply_being_in_education  \
# 0                       None of the above
# 1                  Non chargeable session
# 2                  Non chargeable session
# 3  Value creation(Nothing comes for free)
# 4  Value creation(Nothing comes for free)
#
#                                     role_acceptance  interview_verdict  \
# 0  Yes : Think and says yes.(Shows some hesitation)             Reject
# 1                                      Emphatic Yes             Reject
# 2                                      Emphatic Yes     Premium Select
# 3                                      Emphatic Yes     Premium Select
# 4  Yes : Think and says yes.(Shows some hesitation)  Borderline Select
#
#           candidate_is_willing_to_relocate  \
# 0             Yes - Anywhere Within a City
# 1              Yes - Anywhere in PAN India
# 2             Yes - Anywhere Within a City
# 3              Yes - Anywhere in PAN India
# 4  No - Want Specific Centre Location Only
#
#   role_location_to_be_given_to_the_candidate  \
# 0                                  Bangalore
# 1                                     Delhi
# 2                                   Chennai
# 3                                     Delhi
# 4                                  Bangalore
#
#                                             comments  \
# 0  Lipsa is 25 female from Orissa, Family BG - Fa...
# 1  29 yo / female / unmarried / MSc Finance UK 20...
# 2                                                 nm
# 3  Final Interview Done  22YRS //UTTARAKHAND // F...
# 4  Aniket is 22 male from Bhopal, BA Grad 21, Fam...
#
#                       redflags_comments_in_interview
# 0  At least Graduated ( not 12th Pass or diploma ...
# 1  Not Rehire (CDT have not joined byjus in sales...
# 2  Not working currently and ready to join the R3...
# 3  Not Rehire (CDT have not joined byjus in sales...
# 4  Age is below 32.11, At least Graduated ( not 1...
#
# [5 rows x 35 columns]

# %%
cat_df.columns
# Out:
# Index(['gender', 'type_of_graduation/post_graduation', 'marital_status',
#        'interview_mode', 'pre_interview_check',
#        'fluency_in_english_based_on_introduction',
#        'confidence_based_on_introduction_(english)',
#        'confidence_based_on_the_topic_given',
#        'confidence_based_on_the_ppt_question',
#        'confidence_based_on_the_sales_scenario',
#        'structured_thinking_(in_regional_only)',
#        'structured_thinking_based_on_the_ppt_question',
#        'structured_thinking(_call_pitch)',
#        'regional_fluency_based_on_the_topic_given',
#        'regional_fluency_based_on_the_ppt_question',
#        'regional_fluency_based_on_the__sales_scenario',
#        'mother_tongue_influence', 'acquaintance_in_company',
#        'candidate_status', 'last_fixed_ctc_(lakhs)', 'currently_employed',
#        'experienced_candidate_-_(experience_in_months)',
#        'experienced_candidate_(nature_of_work)', 'what_was_the_type_of_role?',
#        'how_many_slides_candidate_have_submitted_in_ppt?',
#        'call_pitch_elements', 'father_reply',
#        'let_me_discuss_it_with_my_child', 'reply_being_in_education',
#        'role_acceptance', 'interview_verdict',
#        'candidate_is_willing_to_relocate',
#        'role_location_to_be_given_to_the_candidate', 'comments',
#        'redflags_comments_in_interview'],
#       dtype='object')

# %%
# Define the columns to use for creating 'tag'
custom_object_tag = ['gender',
              'type_of_graduation/post_graduation',
              'marital_status',
              'interview_mode',
              'pre_interview_check',
              'fluency_in_english_based_on_introduction',
              'confidence_based_on_introduction_(english)',
              'confidence_based_on_the_topic_given',
              'confidence_based_on_the_ppt_question',
              'confidence_based_on_the_sales_scenario',
              'structured_thinking_(in_regional_only)',
              'structured_thinking_based_on_the_ppt_question',
              'structured_thinking(_call_pitch)',
              'regional_fluency_based_on_the_topic_given',
              'regional_fluency_based_on_the_ppt_question',
              'regional_fluency_based_on_the__sales_scenario',
              'mother_tongue_influence',
              'acquaintance_in_company',
              'candidate_status',
              'last_fixed_ctc_(lakhs)',
              'currently_employed',
              'experienced_candidate_-_(experience_in_months)',
              'experienced_candidate_(nature_of_work)',
              'what_was_the_type_of_role?',
              'how_many_slides_candidate_have_submitted_in_ppt?',
              'call_pitch_elements',
              'father_reply',
              'let_me_discuss_it_with_my_child',
              'reply_being_in_education',
              'role_acceptance',
              'interview_verdict',
              'candidate_is_willing_to_relocate',
              'role_location_to_be_given_to_the_candidate',
              'comments',
              'redflags_comments_in_interview'
             ]

df['meta_tag'] = df[custom_object_tag].fillna('').astype(str).agg(' | '.join, axis=1)
df.head()
# Out:
#      name    age  gender type_of_graduation/post_graduation marital_status  \
# 0  parida  25-27  Female            Masters in data science      Unmarried
# 1  shreej  28-30  Female                         BSc or MSc      Unmarried
# 2  ms6744  25-27  Female                       B.E / B-Tech      Unmarried
# 3  aswalu  22-24    Male                       B.E / B-Tech      Unmarried
# 4  aniket  22-24    Male                              BA/MA      Unmarried
#
#   interview_mode         pre_interview_check  \
# 0         Mobile  Proceed with the Interview
# 1         Mobile  Proceed with the Interview
# 2         Mobile  Proceed with the Interview
# 3         Laptop  Proceed with the Interview
# 4         Mobile  Proceed with the Interview
#
#             fluency_in_english_based_on_introduction  \
# 0  Able to speak sentences in a clear/coherent wa...
# 1  Able to speak sentences in a clear/coherent wa...
# 2  Able to speak sentences in a clear/coherent wa...
# 3  Able to speak sentences in a clear/coherent wa...
# 4  Taking gaps while speaking due to lack of cont...
#
#           confidence_based_on_introduction_(english)  \
# 0  Impactful - Good confidence throughout the Int...
# 1  Impactful - Good confidence throughout the Int...
# 2  Guarded Confidence - Confident in some areas a...
# 3  Impactful - Good confidence throughout the Int...
# 4  Guarded Confidence - Confident in some areas a...
#
#                  confidence_based_on_the_topic_given  ...  \
# 0  Guarded Confidence - Confident in some areas a...  ...
# 1  Impactful - Good confidence throughout the Int...  ...
# 2  Impactful - Good confidence throughout the Int...  ...
# 3  Impactful - Good confidence throughout the Int...  ...
# 4  Impactful - Good confidence throughout the Int...  ...
#
#   structured_thinking_based_on_the_ppt_question.1  \
# 0                                        1.020654
# 1                                        1.020654
# 2                                        1.020654
# 3                                        1.020654
# 4                                       -0.556030
#
#   structured_thinking(_call_pitch).1  \
# 0                          -0.424411
# 1                           1.006713
# 2                           1.006713
# 3                           1.006713
# 4                          -1.855535
#
#   regional_fluency_based_on_the_topic_given__.1  \
# 0                                     -1.092966
# 1                                      0.979581
# 2                                      0.979581
# 3                                      0.979581
# 4                                      0.979581
#
#   regional_fluency_based_on_the_ppt_question.1  \
# 0                                    -1.063625
# 1                                     1.024503
# 2                                    -1.063625
# 3                                     1.024503
# 4                                    -1.063625
#
#   regional_fluency_based_on_the__sales_scenario.1 confidence_score  \
# 0                                       -1.043289         0.951490
# 1                                        1.060405         1.415087
# 2                                        1.060405         0.487893
# 3                                        1.060405         1.415087
# 4                                        1.060405         0.487893
#
#   structured_thinking_score regional_fluency_score total_score  \
# 0                 -0.022276              -1.320677   -0.198863
# 1                  1.256178               1.264403    1.509342
# 2                  1.256178               0.402709    0.750139
# 3                  1.256178               1.264403    1.509342
# 4                 -1.300729               0.402709   -0.009063
#
#                                             meta_tag
# 0  Female | Masters in data science | Unmarried |...
# 1  Female | BSc or MSc | Unmarried | Mobile | Pro...
# 2  Female | B.E / B-Tech | Unmarried | Mobile | P...
# 3  Male | B.E / B-Tech | Unmarried | Laptop | Pro...
# 4  Male | BA/MA | Unmarried | Mobile | Proceed wi...
#
# [5 rows x 53 columns]

# %%
df.drop(columns=custom_object_tag, inplace=True)

# %%
df.shape
# Out:
# (18681, 18)

# %%
df.head()
# Out:
#      name    age  joined_or_not  confidence_based_on_introduction_(english).1  \
# 0  parida  25-27              0                                      1.196219
# 1  shreej  28-30              0                                      1.196219
# 2  ms6744  25-27              1                                     -0.390782
# 3  aswalu  22-24              1                                      1.196219
# 4  aniket  22-24              0                                     -0.390782
#
#    confidence_based_on_the_topic_given__.1  \
# 0                                -0.432008
# 1                                 1.126275
# 2                                 1.126275
# 3                                 1.126275
# 4                                 1.126275
#
#    confidence_based_on_the_ppt_question.1  \
# 0                                1.136634
# 1                                1.136634
# 2                               -0.371960
# 3                                1.136634
# 4                               -0.371960
#
#    confidence_based_on_the_sales_scenario.1  \
# 0                                  1.164132
# 1                                  1.164132
# 2                                  1.164132
# 3                                  1.164132
# 4                                  1.164132
#
#    structured_thinking_(in_regional_only).1  \
# 0                                 -0.618598
# 1                                  0.985514
# 2                                  0.985514
# 3                                  0.985514
# 4                                 -0.618598
#
#    structured_thinking_based_on_the_ppt_question.1  \
# 0                                         1.020654
# 1                                         1.020654
# 2                                         1.020654
# 3                                         1.020654
# 4                                        -0.556030
#
#    structured_thinking(_call_pitch).1  \
# 0                           -0.424411
# 1                            1.006713
# 2                            1.006713
# 3                            1.006713
# 4                           -1.855535
#
#    regional_fluency_based_on_the_topic_given__.1  \
# 0                                      -1.092966
# 1                                       0.979581
# 2                                       0.979581
# 3                                       0.979581
# 4                                       0.979581
#
#    regional_fluency_based_on_the_ppt_question.1  \
# 0                                     -1.063625
# 1                                      1.024503
# 2                                     -1.063625
# 3                                      1.024503
# 4                                     -1.063625
#
#    regional_fluency_based_on_the__sales_scenario.1  confidence_score  \
# 0                                        -1.043289          0.951490
# 1                                         1.060405          1.415087
# 2                                         1.060405          0.487893
# 3                                         1.060405          1.415087
# 4                                         1.060405          0.487893
#
#    structured_thinking_score  regional_fluency_score  total_score  \
# 0                  -0.022276               -1.320677    -0.198863
# 1                   1.256178                1.264403     1.509342
# 2                   1.256178                0.402709     0.750139
# 3                   1.256178                1.264403     1.509342
# 4                  -1.300729                0.402709    -0.009063
#
#                                             meta_tag
# 0  Female | Masters in data science | Unmarried |...
# 1  Female | BSc or MSc | Unmarried | Mobile | Pro...
# 2  Female | B.E / B-Tech | Unmarried | Mobile | P...
# 3  Male | B.E / B-Tech | Unmarried | Laptop | Pro...
# 4  Male | BA/MA | Unmarried | Mobile | Proceed wi...

# %%
df.shape
# Out:
# (18681, 18)

# %%
df.iloc[0, -1]
# Out:
# 'Female | Masters in data science | Unmarried | Mobile | Proceed with the Interview | Able to speak sentences in a clear/coherent way. Smooth talker with one or two hiccups. | Impactful - Good confidence throughout the Introduction with energy | Guarded Confidence - Confident in some areas and ordinary in others | Impactful - Good confidence throughout the Introduction with energy | Impactful - Good confidence throughout the sales scenario with energy | Scripted  : To the point | Logical and Structured : Detailed explanation | Scripted - Product Features/Repetitive content/Not Asking questions | Taking gaps while speaking due to lack of content but does not stammer or stutter | Taking gaps while speaking due to lack of content but does not stammer or stutter | Taking gaps while speaking due to lack of content but does not stammer or stutter | No | No | Experienced in non client facing(equal to or more than 6 months) | 5-5.99 | No | 6-11.99 Months | tech | Fresher | More than 6 slides | Purpose of Call (Book a Counselling Session) | Urgency using Time | None of the above | None of the above | Yes : Think and says yes.(Shows some hesitation) | Reject | Yes - Anywhere Within a City | Bangalore | Lipsa is 25 female from Orissa, Family BG - Father - govt employee, mother - hw, currently residing in U.K - University of shephard - Masters in data science exams over waiting for results, scenario - taking gaps engagement fine countering, overall avg one only from foreign university exams not done, skillset not upto mark, too hesitent abt stipend// reject | At least Graduated ( not 12th Pass or diploma or Final Year student)'

# %%
df.loc[1,'meta_tag']
# Out:
# "Female | BSc or MSc | Unmarried | Mobile | Proceed with the Interview | Able to speak sentences in a clear/coherent way. Smooth talker with one or two hiccups. | Impactful - Good confidence throughout the Introduction with energy | Impactful - Good confidence throughout the Introduction with energy | Impactful - Good confidence throughout the Introduction with energy | Impactful - Good confidence throughout the sales scenario with energy | Logical and Structured : Detailed explanation | Logical and Structured : Detailed explanation | Logical and Structured - when this flow is followed →  Self intro >Company name>Agenda> | Able to speak sentences in a clear/coherent way. Does not stutter or fumble while speaking/ Smooth talker with one or two hiccups. | Able to speak sentences in a clear/coherent way. Does not stutter or fumble while speaking/ Smooth talker with one or two hiccups. | Able to speak sentences in a clear/coherent way. Does not stutter or fumble while speaking/ Smooth talker with one or two hiccups. | No | No | Lateral(2021 and before with (less than 6 months) experience) | Fresher | No | Fresher(<6 months) | Fresher(<6 months) | Fresher | 2 - 3 slides | Introduction (Self Intro,Company Name), Purpose of Call (Book a Counselling Session), Need Generation - By Asking ques like student class, performance etc.. | Asking Questions | None of the above | Non chargeable session | Emphatic Yes | Reject | Yes - Anywhere in PAN India | Delhi  | 29 yo / female / unmarried / MSc Finance UK 2022 / recently relocated to India just 20 days ago / Odissa / father - doctor / bro - software engineer / pursuing internship in investment banking - ends in next week / worked as a teacher / good story teller - fluent in hindi and english - good energy / also prepared for UPSC and GMAT - purchased a course from byju's earlier / cracked GMAT and got business school as well/asking ques in sales scenario - 2/5 | Not Rehire (CDT have not joined byjus in sales before), Not Interviewed in Byjus in sales role in last 90days, Laptop and WiFi are Available, Age is below 32.11, At least Graduated ( not 12th Pass or diploma or Final Year student), Willing to relocate at given location for SSP, Comfortable with the stipend & allowances during training, Not working currently and ready to join the R3 Process"

# %%
df.loc[2,'meta_tag']
# Out:
# 'Female | B.E / B-Tech | Unmarried | Mobile | Proceed with the Interview | Able to speak sentences in a clear/coherent way. Smooth talker with one or two hiccups. | Guarded Confidence - Confident in some areas and ordinary in others | Impactful - Good confidence throughout the Introduction with energy | Guarded Confidence - Confident in some areas and ordinary in others | Impactful - Good confidence throughout the sales scenario with energy | Logical and Structured : Detailed explanation | Logical and Structured : Detailed explanation | Logical and Structured - when this flow is followed →  Self intro >Company name>Agenda> | Able to speak sentences in a clear/coherent way. Does not stutter or fumble while speaking/ Smooth talker with one or two hiccups. | Taking gaps while speaking due to lack of content but does not stammer or stutter | Able to speak sentences in a clear/coherent way. Does not stutter or fumble while speaking/ Smooth talker with one or two hiccups. | Yes | Yes | Fresher(only 2022 grad) | Fresher | Yes | Fresher(<6 months) | Fresher(<6 months) | Individual Contributor | 5 - 6 slides | Introduction (Self Intro,Company Name) | Urgency using Time | Decision Making: Major decision of child future/study is taken by parents as parents know the importance of it. | Non chargeable session | Emphatic Yes | Premium Select | Yes - Anywhere Within a City | Chennai  | nm | Not working currently and ready to join the R3 Process'

# %%
df.loc[3,'meta_tag']
# Out:
# 'Male | B.E / B-Tech | Unmarried | Laptop | Proceed with the Interview | Able to speak sentences in a clear/coherent way. Smooth talker with one or two hiccups. | Impactful - Good confidence throughout the Introduction with energy | Impactful - Good confidence throughout the Introduction with energy | Impactful - Good confidence throughout the Introduction with energy | Impactful - Good confidence throughout the sales scenario with energy | Logical and Structured : Detailed explanation | Logical and Structured : Detailed explanation | Logical and Structured - when this flow is followed →  Self intro >Company name>Agenda> | Able to speak sentences in a clear/coherent way. Does not stutter or fumble while speaking/ Smooth talker with one or two hiccups. | Able to speak sentences in a clear/coherent way. Does not stutter or fumble while speaking/ Smooth talker with one or two hiccups. | Able to speak sentences in a clear/coherent way. Does not stutter or fumble while speaking/ Smooth talker with one or two hiccups. | No | No | Fresher(only 2022 grad) | Fresher | No | Fresher(<6 months) | Fresher(<6 months) | Fresher | 5 - 6 slides | Introduction (Self Intro,Company Name), Purpose of Call (Book a Counselling Session), Rapport Building - Connect with Customer by asking ques like customer background, location, language, education etc., Need Generation - By Asking ques like student class, performance etc.. | Urgency using Time, Urgency using situation | None of the above | Value creation(Nothing comes for free) | Emphatic Yes | Premium Select | Yes - Anywhere in PAN India | Delhi  | Final Interview Done  22YRS //UTTARAKHAND // FATHER IS EX- NAVY EMPLOYEE// MOTHER IS HOUSEWIFE//2022 BTECH EEE PASS OUT // FRESHER // NO-ACQUITTANCE // PERFORMED WELL IN EXTEMPORE AND SS //NOT INTERESTED IN GOVT SECTOR // AS CDT PERFORMED WELL DECENT IN HINDI & ENGLISH AS WELL// EMPAHTIC YES -ROLE ACCEPTANCE// AS CDT DISCUSSED WITH HIS FATHER REGARDING THIS AS WELL// 22ND NOV //\n | Not Rehire (CDT have not joined byjus in sales before), Not Interviewed in Byjus in sales role in last 90days, Laptop and WiFi are Available, Age is below 32.11, At least Graduated ( not 12th Pass or diploma or Final Year student), Willing to relocate at given location for SSP, Comfortable with the stipend & allowances during training, Not working currently and ready to join the R3 Process'

# %%
# pip install -U spacy[cuda]

# %%
import spacy
spacy.require_gpu()  # Forces  use GPU if available
nlp = spacy.load("en_core_web_sm", disable=["ner", "parser"])

# %%
# nlp = spacy.load("en_core_web_sm")

# def clean_text(text):
#     doc = nlp(text.lower())  
#     filtered_words = [token.lemma_ for token in doc if not token.is_stop and token.is_alpha]  
#     return " ".join(filtered_words)

# df['meta_tag_cleaned'] = df['meta_tag'].astype(str).apply(clean_text)

# %%
# df['meta_tag_cleaned']

# %%
nlp = spacy.load("en_core_web_sm", disable=["ner", "parser"])

def clean_text_pipe(texts):
    return [
        " ".join([token.lemma_ for token in doc if not token.is_stop and token.is_alpha])
        for doc in nlp.pipe(texts, batch_size=100)
    ]

df['meta_tag_cleaned'] = clean_text_pipe(df['meta_tag'].astype(str))
# Out:
# /usr/local/lib/python3.10/dist-packages/spacy/util.py:1740: UserWarning: [W111] Jupyter notebook detected: if using `prefer_gpu()` or `require_gpu()`, include it in the same cell right before `spacy.load()` to ensure that the model is loaded on the correct device. More information: http://spacy.io/usage/v3#jupyter-notebook-gpu
#   warnings.warn(Warnings.W111)

# %%
df['meta_tag_cleaned'].head()
# Out:
# 0    female Masters datum science Unmarried Mobile ...
# 1    female BSc MSc Unmarried Mobile proceed Interv...
# 2    female B tech Unmarried Mobile proceed Intervi...
# 3    male B tech Unmarried Laptop proceed Interview...
# 4    male BA MA Unmarried Mobile proceed Interview ...
# Name: meta_tag_cleaned, dtype: object

# %%
df
# Out:
#          name    age  joined_or_not  \
# 0      parida  25-27              0
# 1      shreej  28-30              0
# 2      ms6744  25-27              1
# 3      aswalu  22-24              1
# 4      aniket  22-24              0
# ...       ...    ...            ...
# 18676  rajivt  28-30              1
# 18677  amitmk  25-27              0
# 18678  Seshag  31-32              0
# 18679  melbin  25-27              0
# 18680  Abbind  28-30              0
#
#        confidence_based_on_introduction_(english).1  \
# 0                                          1.196219
# 1                                          1.196219
# 2                                         -0.390782
# 3                                          1.196219
# 4                                         -0.390782
# ...                                             ...
# 18676                                      1.196219
# 18677                                     -0.390782
# 18678                                      1.196219
# 18679                                      1.196219
# 18680                                      1.196219
#
#        confidence_based_on_the_topic_given__.1  \
# 0                                    -0.432008
# 1                                     1.126275
# 2                                     1.126275
# 3                                     1.126275
# 4                                     1.126275
# ...                                        ...
# 18676                                 1.126275
# 18677                                 1.126275
# 18678                                 1.126275
# 18679                                 1.126275
# 18680                                -0.432008
#
#        confidence_based_on_the_ppt_question.1  \
# 0                                    1.136634
# 1                                    1.136634
# 2                                   -0.371960
# 3                                    1.136634
# 4                                   -0.371960
# ...                                       ...
# 18676                                1.136634
# 18677                               -0.371960
# 18678                                1.136634
# 18679                                1.136634
# 18680                               -0.371960
#
#        confidence_based_on_the_sales_scenario.1  \
# 0                                      1.164132
# 1                                      1.164132
# 2                                      1.164132
# 3                                      1.164132
# 4                                      1.164132
# ...                                         ...
# 18676                                  1.164132
# 18677                                  1.164132
# 18678                                  1.164132
# 18679                                 -0.251330
# 18680                                  1.164132
#
#        structured_thinking_(in_regional_only).1  \
# 0                                     -0.618598
# 1                                      0.985514
# 2                                      0.985514
# 3                                      0.985514
# 4                                     -0.618598
# ...                                         ...
# 18676                                  0.985514
# 18677                                 -0.618598
# 18678                                  0.985514
# 18679                                  0.985514
# 18680                                 -0.618598
#
#        structured_thinking_based_on_the_ppt_question.1  \
# 0                                             1.020654
# 1                                             1.020654
# 2                                             1.020654
# 3                                             1.020654
# 4                                            -0.556030
# ...                                                ...
# 18676                                        -0.556030
# 18677                                        -0.556030
# 18678                                         1.020654
# 18679                                         1.020654
# 18680                                         1.020654
#
#        structured_thinking(_call_pitch).1  \
# 0                               -0.424411
# 1                                1.006713
# 2                                1.006713
# 3                                1.006713
# 4                               -1.855535
# ...                                   ...
# 18676                            1.006713
# 18677                            1.006713
# 18678                            1.006713
# 18679                            1.006713
# 18680                           -0.424411
#
#        regional_fluency_based_on_the_topic_given__.1  \
# 0                                          -1.092966
# 1                                           0.979581
# 2                                           0.979581
# 3                                           0.979581
# 4                                           0.979581
# ...                                              ...
# 18676                                      -1.092966
# 18677                                       0.979581
# 18678                                       0.979581
# 18679                                       0.979581
# 18680                                      -1.092966
#
#        regional_fluency_based_on_the_ppt_question.1  \
# 0                                         -1.063625
# 1                                          1.024503
# 2                                         -1.063625
# 3                                          1.024503
# 4                                         -1.063625
# ...                                             ...
# 18676                                     -1.063625
# 18677                                      1.024503
# 18678                                      1.024503
# 18679                                      1.024503
# 18680                                     -1.063625
#
#        regional_fluency_based_on_the__sales_scenario.1  confidence_score  \
# 0                                            -1.043289          0.951490
# 1                                             1.060405          1.415087
# 2                                             1.060405          0.487893
# 3                                             1.060405          1.415087
# 4                                             1.060405          0.487893
# ...                                                ...               ...
# 18676                                         1.060405          1.415087
# 18677                                         1.060405          0.487893
# 18678                                         1.060405          1.415087
# 18679                                         1.060405          0.951490
# 18680                                        -1.043289          0.487893
#
#        structured_thinking_score  regional_fluency_score  total_score  \
# 0                      -0.022276               -1.320677    -0.198863
# 1                       1.256178                1.264403     1.509342
# 2                       1.256178                0.402709     0.750139
# 3                       1.256178                1.264403     1.509342
# 4                      -1.300729                0.402709    -0.009063
# ...                          ...                     ...          ...
# 18676                   0.616951               -0.458984     0.560339
# 18677                  -0.022276                1.264403     0.750139
# 18678                   1.256178                1.264403     1.509342
# 18679                   1.256178                1.264403     1.319541
# 18680                  -0.022276               -1.320677    -0.388664
#
#                                                 meta_tag  \
# 0      Female | Masters in data science | Unmarried |...
# 1      Female | BSc or MSc | Unmarried | Mobile | Pro...
# 2      Female | B.E / B-Tech | Unmarried | Mobile | P...
# 3      Male | B.E / B-Tech | Unmarried | Laptop | Pro...
# 4      Male | BA/MA | Unmarried | Mobile | Proceed wi...
# ...                                                  ...
# 18676  Male | BSc or MSc | Unmarried | Mobile | Proce...
# 18677  Male | B.E / B-Tech | Unmarried | Mobile | Pro...
# 18678  Male | B.ARC | Married | Laptop | Proceed with...
# 18679  Male | B.E / B-Tech | Unmarried | Mobile | Pro...
# 18680  Male | MBA | Married | Mobile | Proceed with t...
#
#                                         meta_tag_cleaned
# 0      female Masters datum science Unmarried Mobile ...
# 1      female BSc MSc Unmarried Mobile proceed Interv...
# 2      female B tech Unmarried Mobile proceed Intervi...
# 3      male B tech Unmarried Laptop proceed Interview...
# 4      male BA MA Unmarried Mobile proceed Interview ...
# ...                                                  ...
# 18676  male BSc MSc Unmarried Mobile proceed Intervie...
# 18677  male B tech Unmarried Mobile proceed Interview...
# 18678  male married Laptop proceed Interview able spe...
# 18679  male B tech Unmarried Mobile proceed Interview...
# 18680  male MBA Married Mobile proceed Interview able...
#
# [18681 rows x 19 columns]

# %%
df.loc[3,'meta_tag_cleaned']
# Out:
# 'male B tech Unmarried Laptop proceed Interview able speak sentence clear coherent way smooth talker hiccup Impactful good confidence introduction energy impactful good confidence introduction energy impactful good confidence introduction energy impactful good confidence sale scenario energy Logical Structured detailed explanation Logical Structured detailed explanation Logical Structured flow follow Self intro Company Agenda able speak sentence clear coherent way stutter fumble Smooth talker hiccup able speak sentence clear coherent way stutter fumble Smooth talker hiccup able speak sentence clear coherent way stutter fumble Smooth talker hiccup grad Fresher month month Fresher slide introduction Self Intro Company Purpose Book Counselling Session Rapport Building Connect Customer ask que like customer background location language education etc need Generation ask que like student class performance etc Urgency Time urgency situation Value come free Emphatic yes Premium Select yes PAN India Delhi Final Interview FATHER NAVY MOTHER BTECH EEE pass FRESHER acquittance PERFORMED EXTEMPORE SS interested GOVT SECTOR CDT PERFORMED DECENT HINDI ENGLISH EMPAHTIC yes CDT discuss FATHER NOV Rehire CDT join byju sale interview Byjus sale role Laptop WiFi available Age Graduated Pass diploma Final Year student willing relocate give location SSP comfortable stipend allowance training work currently ready join process'

# %%
df = df.drop(columns=['meta_tag'])
df.shape
# Out:
# (18681, 18)

# %%
df = df.drop(columns=['name'])
df.shape
# Out:
# (18681, 17)

# %%
df
# Out:
#          age  joined_or_not  confidence_based_on_introduction_(english).1  \
# 0      25-27              0                                      1.196219
# 1      28-30              0                                      1.196219
# 2      25-27              1                                     -0.390782
# 3      22-24              1                                      1.196219
# 4      22-24              0                                     -0.390782
# ...      ...            ...                                           ...
# 18676  28-30              1                                      1.196219
# 18677  25-27              0                                     -0.390782
# 18678  31-32              0                                      1.196219
# 18679  25-27              0                                      1.196219
# 18680  28-30              0                                      1.196219
#
#        confidence_based_on_the_topic_given__.1  \
# 0                                    -0.432008
# 1                                     1.126275
# 2                                     1.126275
# 3                                     1.126275
# 4                                     1.126275
# ...                                        ...
# 18676                                 1.126275
# 18677                                 1.126275
# 18678                                 1.126275
# 18679                                 1.126275
# 18680                                -0.432008
#
#        confidence_based_on_the_ppt_question.1  \
# 0                                    1.136634
# 1                                    1.136634
# 2                                   -0.371960
# 3                                    1.136634
# 4                                   -0.371960
# ...                                       ...
# 18676                                1.136634
# 18677                               -0.371960
# 18678                                1.136634
# 18679                                1.136634
# 18680                               -0.371960
#
#        confidence_based_on_the_sales_scenario.1  \
# 0                                      1.164132
# 1                                      1.164132
# 2                                      1.164132
# 3                                      1.164132
# 4                                      1.164132
# ...                                         ...
# 18676                                  1.164132
# 18677                                  1.164132
# 18678                                  1.164132
# 18679                                 -0.251330
# 18680                                  1.164132
#
#        structured_thinking_(in_regional_only).1  \
# 0                                     -0.618598
# 1                                      0.985514
# 2                                      0.985514
# 3                                      0.985514
# 4                                     -0.618598
# ...                                         ...
# 18676                                  0.985514
# 18677                                 -0.618598
# 18678                                  0.985514
# 18679                                  0.985514
# 18680                                 -0.618598
#
#        structured_thinking_based_on_the_ppt_question.1  \
# 0                                             1.020654
# 1                                             1.020654
# 2                                             1.020654
# 3                                             1.020654
# 4                                            -0.556030
# ...                                                ...
# 18676                                        -0.556030
# 18677                                        -0.556030
# 18678                                         1.020654
# 18679                                         1.020654
# 18680                                         1.020654
#
#        structured_thinking(_call_pitch).1  \
# 0                               -0.424411
# 1                                1.006713
# 2                                1.006713
# 3                                1.006713
# 4                               -1.855535
# ...                                   ...
# 18676                            1.006713
# 18677                            1.006713
# 18678                            1.006713
# 18679                            1.006713
# 18680                           -0.424411
#
#        regional_fluency_based_on_the_topic_given__.1  \
# 0                                          -1.092966
# 1                                           0.979581
# 2                                           0.979581
# 3                                           0.979581
# 4                                           0.979581
# ...                                              ...
# 18676                                      -1.092966
# 18677                                       0.979581
# 18678                                       0.979581
# 18679                                       0.979581
# 18680                                      -1.092966
#
#        regional_fluency_based_on_the_ppt_question.1  \
# 0                                         -1.063625
# 1                                          1.024503
# 2                                         -1.063625
# 3                                          1.024503
# 4                                         -1.063625
# ...                                             ...
# 18676                                     -1.063625
# 18677                                      1.024503
# 18678                                      1.024503
# 18679                                      1.024503
# 18680                                     -1.063625
#
#        regional_fluency_based_on_the__sales_scenario.1  confidence_score  \
# 0                                            -1.043289          0.951490
# 1                                             1.060405          1.415087
# 2                                             1.060405          0.487893
# 3                                             1.060405          1.415087
# 4                                             1.060405          0.487893
# ...                                                ...               ...
# 18676                                         1.060405          1.415087
# 18677                                         1.060405          0.487893
# 18678                                         1.060405          1.415087
# 18679                                         1.060405          0.951490
# 18680                                        -1.043289          0.487893
#
#        structured_thinking_score  regional_fluency_score  total_score  \
# 0                      -0.022276               -1.320677    -0.198863
# 1                       1.256178                1.264403     1.509342
# 2                       1.256178                0.402709     0.750139
# 3                       1.256178                1.264403     1.509342
# 4                      -1.300729                0.402709    -0.009063
# ...                          ...                     ...          ...
# 18676                   0.616951               -0.458984     0.560339
# 18677                  -0.022276                1.264403     0.750139
# 18678                   1.256178                1.264403     1.509342
# 18679                   1.256178                1.264403     1.319541
# 18680                  -0.022276               -1.320677    -0.388664
#
#                                         meta_tag_cleaned
# 0      female Masters datum science Unmarried Mobile ...
# 1      female BSc MSc Unmarried Mobile proceed Interv...
# 2      female B tech Unmarried Mobile proceed Intervi...
# 3      male B tech Unmarried Laptop proceed Interview...
# 4      male BA MA Unmarried Mobile proceed Interview ...
# ...                                                  ...
# 18676  male BSc MSc Unmarried Mobile proceed Intervie...
# 18677  male B tech Unmarried Mobile proceed Interview...
# 18678  male married Laptop proceed Interview able spe...
# 18679  male B tech Unmarried Mobile proceed Interview...
# 18680  male MBA Married Mobile proceed Interview able...
#
# [18681 rows x 17 columns]
